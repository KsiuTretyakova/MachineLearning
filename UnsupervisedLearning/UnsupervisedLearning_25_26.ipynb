# %% [markdown]
# <a href="https://colab.research.google.com/github/KsiuTretyakova/MachineLearning/blob/main/UnsupervisedLearning/UnsupervisedLearning_25_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
np.random.seed(42)
X = np.vstack((np.random.randn(50, 2) + [2, 2], np.random.randn(50, 2) + [7, 7]))

# %%
print(np.random.randn(50, 2) + [2, 2])
# Out:
# [[ 2.35778736  2.56078453]
#  [ 3.08305124  3.05380205]
#  [ 0.62233063  1.06217496]
#  [ 2.51503527  2.51378595]
#  [ 2.51504769  5.85273149]
#  [ 2.57089051  3.13556564]
#  [ 2.95400176  2.65139125]
#  [ 1.68473076  2.75896922]
#  [ 1.22717479  1.76318139]
#  [ 1.51463645  2.08187414]
#  [ 4.31465857  0.13273481]
#  [ 2.68626019  0.38728413]
#  [ 1.52806813  3.0889506 ]
#  [ 2.06428002  0.92225522]
#  [ 1.28469629  2.67959775]
#  [ 1.26963337  2.21645859]
#  [ 2.04557184  1.34839965]
#  [ 4.14394409  2.63391902]
#  [-0.02514259  2.18645431]
#  [ 1.33821354  2.85243333]
#  [ 1.20747926  1.88526356]
#  [ 2.50498728  2.86575519]
#  [ 0.79970359  1.66549876]
#  [ 1.52505469  1.34667077]
#  [ 3.76545424  2.40498171]
#  [ 0.73911605  2.91786195]
#  [ 4.1221562   3.03246526]
#  [ 0.48063003  1.51576593]
#  [ 3.26691115  1.29233053]
#  [ 2.44381943  2.77463405]
#  [ 1.07306953  1.94047464]
#  [-1.24126734  0.97561236]
#  [ 1.74743185  0.75221682]
#  [ 3.6324113   0.56985862]
# ...

# %%
plt.scatter(X[:,0], X[:,1], s=50, color='gray')
plt.title("Вихідні дані")
plt.xlabel("X1")
plt.ylabel("X2")
plt.show()

# %%
kmeans = KMeans(n_clusters=10, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=10, random_state=42)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

print(labels)
print(centroids)
# Out:
# [4 3 5 4 5 5 9 2 5 2 4 9 5 5 5 3 9 9 9 5 4 5 2 3 9 4 5 3 5 3 5 2 3 3 4 3 3
#  0 5 9 5 4 2 4 5 3 5 9 4 5 8 7 1 1 1 8 6 1 7 1 7 7 6 8 7 8 8 6 8 7 6 8 1 8
#  1 1 8 7 1 8 8 7 1 6 7 8 1 1 6 6 7 8 1 1 7 1 7 1 8 7]
# [[-0.6197451   2.8219025 ]
#  [ 7.43565064  7.43254723]
#  [ 0.7947415   1.12152018]
#  [ 2.21107689  3.27703537]
#  [ 2.85057542  1.95734406]
#  [ 1.45444916  2.02197373]
#  [ 7.07507546  8.94018159]
#  [ 7.3066942   5.99492173]
#  [ 5.83888522  6.9690781 ]
#  [ 2.17133408  0.40120286]]

# %%
plt.scatter(X[:,0], X[:,1], s=50, c=labels, cmap='viridis')
plt.scatter(
    centroids[:,0],
    centroids[:,1],
    c="red",
    marker="x",
    s=200,
    label='Центроїди'
    )
plt.title("Результат кластеризації")
plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.show()
